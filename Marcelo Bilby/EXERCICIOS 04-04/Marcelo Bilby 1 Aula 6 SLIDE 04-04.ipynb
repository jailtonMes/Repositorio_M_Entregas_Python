# %% [markdown]
# **Exercício 5.1**

# %%
a = 10 + 20 * 30
print(a)
# Out:
# 610

# %%
b = 42 / 30
print(b)
# Out:
# 1.4

# %%
c = ((94 + 2) * (6 - 1))
print(c)
# Out:
# 480

# %%
d = ((10 + 8) * (10 - 4)) - 1
print(d)
# Out:
# 107

# %%
e = ((1500+((100 - 9)/10)) * 9) ** 3
print(e)
# Out:
# 2505426032558.259

# %% [markdown]
# **Exercícios 5.2**

# %%
a = 10 % 3 * 10 ** 2 + 1 -10 * 4 / 2
print(a)
# Out:
# 81.0

# %% [markdown]
# **Exercício 5.3**

# %%
print("Marcelo Bilby")
# Out:
# Marcelo Bilby

# %% [markdown]
# **Exercício 5.4**

# %%
a = 3
b = 5
result = (2 * a) * (3 * b)
print(result)
# Out:
# 90

# %% [markdown]
# **Exercício 5.5"

# %%
a = 2
b = 3
c = 5

result = a + b + c
print(result)
# Out:
# 10

# %% [markdown]
# **Exercício 5.6**

# %%
salario = 750
taxa = 15
print("Seu salário reajustado é: ", salario + (salario * taxa / 100))
# Out:
# Seu salário reajustado é:  862.5

# %%
**Exercício 5.7**

# %%
cm = float(input("Informe seu valor em centimetros: "))
result = cm / 100
print("Seu valor em centimetros corresponde a: ", result, "Metros")
# Out:
# Informe seu valor em centimetros: 50
# Seu valor em centimetros corresponde a:  0.5 Metros

# %% [markdown]
# **Exercício 5.8**

# %%
valor = int(input("Informe um valor: "))

print(f"1 x {valor} = ", 1 * valor )
print(f"2 x {valor} = ", 2 * valor )
print(f"3 x {valor} = ", 3 * valor )
print(f"4 x {valor} = ", 4 * valor )
print(f"5 x {valor} = ", 5 * valor )
print(f"6 x {valor} = ", 6 * valor )
print(f"7 x {valor} = ", 7 * valor )
print(f"8 x {valor} = ", 8 * valor )
print(f"9 x {valor} = ", 9 * valor )
print(f"10 x {valor} = ", 10 * valor )
# Out:
# Informe um valor: 9
# 1 x 9 =  9
# 2 x 9 =  18
# 3 x 9 =  27
# 4 x 9 =  36
# 5 x 9 =  45
# 6 x 9 =  54
# 7 x 9 =  63
# 8 x 9 =  72
# 9 x 9 =  81
# 10 x 9 =  90

# %% [markdown]
# **Exercício 5.9**

# %%
a = float(input("Informe a primeira nota: "))
b = float(input("Informe a segunda nota: "))
media = (a + b) / 2
print(f"Sua média é: {media}")

# %% [markdown]
# **Exercício 5.10**

# %%
salario = float(input("Informe seu salario atual: "))
taxa = float(input("Informe a taxa a ser utilizada 5%, 10% ou 15% : "))
salario = salario + (salario * (taxa / 100))
print("O seu salário reajustado é: ", salario)
# Out:
# Informe seu salario atual: 1000
# Informe a taxa a ser utilizada 5%, 10% ou 15% : 15
# O seu salário reajustado é:  1150.0

# %% [markdown]
# **Exercício 5.13**

# %%
carro = float(input("Quantos quilometros seu carro realiza por Litros de combustivel:  "))
combustivel = float(input("Informe o valor do combustivel:  "))
distancia = int(input("Informe a distância percorrida em KM: "))
valor = distancia * (combustivel / carro)


print(f"Resultado: Foram utlizados {valor} para rodar {distancia} KM." )
# Out:
# Quantos quilometros seu carro realiza por Litros de combustivel:  12.50
# Informe o valor do combustivel:  8.50
# Informe a distância percorrida em KM: 400
# Resultado: Foram utlizados 272.0 para rodar 400 KM.

# %% [markdown]
# **Exercício 5.14**

# %%
nome = input("Informe seu nome: ")
salario = float(input("Informe seu salário: "))
vendas = float(input("Informe o valor total de suas vendas: "))
taxa = 15

res = salario + ((vendas * 15)/100)

print("Nome: ", nome)
print("Salário Fixo: ", salario)
print("Salário Total: ", res)
# Out:
# Informe seu nome: Marcelo
# Informe seu salário: 1500
# Informe o valor total de suas vendas: 2000
# Nome:  Marcelo
# Salário Fixo:  1500.0
# Salário Total:  1800.0

# %% [markdown]
# **Exercício 5.15**

# %%
nome = input("Informe seu nome: ")
acc = 0

for i in range(1, 4):
     nota = float(input(f"Informe a nota {i}° do {nome}: "))
     acc += nota

media = acc / 3

print(f"A média do {nome} é {media:5.2}")
# Out:
# Informe seu nome: Marcelo
# Informe a nota 1° do Marcelo: 9.8
# Informe a nota 2° do Marcelo: 9.7
# Informe a nota 3° do Marcelo: 9.6
# A média do Marcelo é   9.7

# %% [markdown]
# **Exercício 5.16**

# %%
a = int(input("Informe o valor de A: "))
b = int(input("Informe o valor de B: "))
aux = 0
c = a
d = b

aux = a
a = b
b = aux

print(f"Você informou os seguintes valores A: {c} e B: {d}")
print(f"As trocas de valores é igual A: {a} e B: {b}")
# Out:
# Informe o valor de A: 9
# Informe o valor de B: 8
# Você informou os seguintes valores A: 9 e B: 8
# As trocas de valores é igual A: 8 e B: 9
